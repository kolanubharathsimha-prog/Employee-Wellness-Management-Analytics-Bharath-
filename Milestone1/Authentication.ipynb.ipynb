# %%
import smtplib, re
import random
from email.mime.text import MIMEText

sender = "kolanubharathsimhareddybannu@gmail.com"
app_password = "nqgpndfvfclmgbjk"

# Email Validation Function

def is_valid_email(email):
    pattern = r'^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$'
    return re.fullmatch(pattern, email) is not None

# Keep Asking Until Valid Email

while True:
    receiver = input("Enter your Email: ").strip()

    if is_valid_email(receiver):
        break
    else:
        print("❌ Invalid Email Address! Please enter a valid email.\n")

otp = random.randint(100000,999999)

msg = MIMEText(f"Your OTP is {otp}")
msg["Subject"] = "MoodMentor OTP"
msg["From"] = sender
msg["To"] = receiver

server = smtplib.SMTP("smtp.gmail.com",587)
server.starttls()
server.login(sender, app_password)
server.sendmail(sender, receiver, msg.as_string())
server.quit()

print("OTP Sent!")
print("OTP =", otp)

entered_otp = input("Enter the OTP received in your email: ")

if entered_otp == str(otp):
    print("✅ Email Verified Successfully!")
else:
    print("❌ Invalid OTP")
# Out:
# Enter your Email: kolanubharathsimha@gmail.com
# OTP Sent!
# OTP = 981836
# Enter the OTP received in your email: 981836
# ✅ Email Verified Successfully!

# %%
import jwt
from datetime import datetime, timedelta, UTC

SECRET_KEY = "MoodMentor123456789012345678901234567890"
# For HS256, the recommended secret key length is at least 32 bytes.

payload = {
    "email": receiver,
    "exp": datetime.now(UTC) + timedelta(hours=1)
}

token = jwt.encode(payload, SECRET_KEY, algorithm="HS256")

print("JWT Token:")
print(token)
# Out:
# JWT Token:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImtvbGFudWJoYXJhdGhzaW1oYUBnbWFpbC5jb20iLCJleHAiOjE3ODM0NDg0ODV9.vfJAUp5BbQkYNuXBGZ5e9vekDSUR3gJPQMRZnonaPBs

# %%
try:
    decoded = jwt.decode(token, SECRET_KEY, algorithms=["HS256"])
    print("Token is Valid")
    print(decoded)
except jwt.ExpiredSignatureError:
    print("Token Expired")
except jwt.InvalidTokenError:
    print("Invalid Token")
# Out:
# Token is Valid
# {'email': 'kolanubharathsimha@gmail.com', 'exp': 1783448485}

# %%
# !pip install streamlit   --q

# %%
# %%writefile app.py
import streamlit as st

st.markdown("""
<style>
.stApp{background-color: lightblue;
}
</style>
""", unsafe_allow_html=True)
st.set_page_config(
    page_title="MoodMentor",
    page_icon="😊",
    layout="centered"
)

st.title("😊 MoodMentor")

st.subheader("AI-Powered Emotional Wellness System")

choice = st.sidebar.selectbox(
    "Menu",
    ["Home", "Register", "Login"]
)

if choice == "Home":
    st.write("Welcome to MoodMentor")

elif choice == "Register":
    st.header("Register")

elif choice == "Login":
    st.header("Login")

st.header("Create Account")

email = st.text_input("Email")

password = st.text_input(
    "Password",
    type="password"
)

confirm = st.text_input(
    "Confirm Password",
    type="password"
)

if st.button("Send OTP"):
    st.success("OTP Sent")

otp = st.text_input("Enter OTP")

if st.button("Verify OTP"):
    st.success("Email Verified")

st.header("Login")

login_email = st.text_input("Email")

login_password = st.text_input(
    "Password",
    type="password"
)

if st.button("Login"):
    st.success("JWT Generated")

st.title("Dashboard")

st.success("Welcome!")

st.metric("Current Mood", "😊 Happy")

st.metric("Sentiment", "Positive")

menu = st.sidebar.radio(
    "Navigation",
    [
        "Home",
        "Analyze",
        "History",
        "Profile",
        "Logout"
    ]
)
# Out:
# Writing app.py

# %%
# !pip install -q streamlit pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 74.5 MB/s eta 0:00:00

# %%
from pyngrok import ngrok

# Set your auth token
ngrok.set_auth_token("3FqnPrgH4oolsScmhs8DHFPKDnh_5iaDZMmHFSUHX8gDYjoRm")

# %%
from pyngrok import ngrok
ngrok.kill()

ngrok.set_auth_token("YOUR_NGROK_AUTH_TOKEN")

tunnel = ngrok.connect(addr=8503, proto="http")
print(tunnel.public_url)
# Out:
# ERROR:pyngrok.process.ngrok:t=2026-07-07T17:52:29+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: YOUR_NGROK_AUTH_TOKEN\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_1928/1179270683.py in <cell line: 0>()
#       4 ngrok.set_auth_token("YOUR_NGROK_AUTH_TOKEN")
#       5
# ----> 6 tunnel = ngrok.connect(addr=8503, proto="http")
#       7 print(tunnel.public_url)
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     387     logger.info(f"Opening tunnel named: {name}")
#     388
# --> 389     api_url = get_ngrok_process(pyngrok_config).api_url
#     390
#     391     logger.debug(f"Creating tunnel with options: {options}")
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in get_ngrok_process(pyngrok_config)
#     215     install_ngrok(pyngrok_config)
#     216
# --> 217     return process.get_process(pyngrok_config)
#     218
#     219
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in get_process(pyngrok_config)
#     271         return _current_processes[pyngrok_config.ngrok_path]
#     272
# --> 273     return _start_process(pyngrok_config)
#     274
#     275
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in _start_process(pyngrok_config)
#     447
#     448         if ngrok_process.startup_error is not None:
# --> 449             raise PyngrokNgrokError(f"The ngrok process errored on start: {ngrok_process.startup_error}.",
#     450                                     ngrok_process.logs,
#     451                                     ngrok_process.startup_error)
#
# PyngrokNgrokError: The ngrok process errored on start: authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: YOUR_NGROK_AUTH_TOKEN\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n.

# %%
# !ngrok version
# Out:
# ngrok version 3.39.9
# pyngrok version 8.1.2
